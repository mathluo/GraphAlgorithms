# %%
# Preamble  here, add paths and import relevant modules
import os
import sys
base_path = '/'.join(os.getcwd().split('/')[:-1])
sys.path.append('/'.join(os.getcwd().split('/')[:-1]))
import util
reload(util)
import numpy as np 
import sklearn
from sklearn import datasets
from scipy.sparse.linalg import eigsh
from numpy.random import permutation
from scipy import ndimage
from scipy import misc
% matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # Tutorial 3 --  Nystrom Extension

# %% [markdown]
# `Nystrom Extension` is a way of computing *approximately* the eigenvectors of a graph Laplacian. It is a sampling strategy to bypass the $O(N^2)$ complexity in constructing the full Laplalacian Matrix. Since it's a sampling strategy, we need the graph to be well-connected enough so that the samples correctly reflect the geometry of the original graph

# %% [markdown]
# We load the test image `Two Cows` and use Nystrom Extension to compute its kernels. Since we are clustering, it's no surprise that the names of our datasets start with a number.

# %%
# load the two cows image
img = np.float32(misc.imresize(misc.imread(base_path+'/data/Images/twocows.png'),(256,256)))/255.
#initialization
import graph_cluster as gc
reload(gc)
gl_clf = gc.LaplacianClustering()
gl_clf.load_raw_data(util.imageblocks(img, width = 2)) #patch size = 2*width + 1
plt.imshow(img)
plt.rcParams['figure.figsize'] = (5, 5)
plt.axis('off')
plt.show()

# %% [markdown]
# To use Nystrom, simply switch the `Eig_solver` property to 'nystrom'. Currently the affinity only supports 'rbf' kernel, with either cosine or euclidean distance metric.

# %%
gl_clf.set_graph_parameters(Neig = 100,Eig_solver = 'nystrom')
gl_clf.build_Laplacian()

# %% [markdown]
# Below is a visualization of the eigenvectors we have just computed.

# %%
v = gl_clf.laplacian_matrix_['V']
e = gl_clf.laplacian_matrix_['E']
plt.figure(2)
for i in range(1,4):
    plt.subplot(1,3,i)
    plt.imshow(v[:,i].reshape(img.shape[0],img.shape[1]))
    plt.axis('off')
plt.rcParams['figure.figsize'] = (10, 5)
plt.tight_layout()  
plt.show()

# %% [markdown]
# This image roughly has four regions, and the eigenvectors clearly reflect those regions. But what about images that have less clear delineations? We'll next try the `lena` image.

# %%
# load the two cows image
img = np.float32(misc.imresize(misc.imread(base_path+'/data/Images/lena.png'),(256,256)))/255.
gl_clf.set_graph_parameters(Neig = 100,Eig_solver = 'nystrom')
gl_clf.load_raw_data(util.imageblocks(img, width = 2)) #patch size = 2*width + 1
gl_clf.build_Laplacian()

# %%
v = gl_clf.laplacian_matrix_['V']
e1 = gl_clf.laplacian_matrix_['E']
plt.figure(2)
for i in range(3):
    for j in range(3):
        plt.subplot(3,3,i*3+j+1)
        plt.imshow(v[:,i*3+j+1].reshape(img.shape[0],img.shape[1]))
        plt.axis('off')
plt.rcParams['figure.figsize'] = (10, 10)
plt.tight_layout()  
plt.show()

# %% [markdown]
# We see that the eigenvalues are much more complicated, and capture some of the variation along the edges. However, the several of the eigenvalues seems to be blank. This is an indicator that we need to adjust the kernel width $\gamma$ to adjust the graph-sparsity. We'll reset the kernel width and see how it affects the eigenvalues.

# %%
gl_clf.set_graph_parameters(Neig = 100,Eig_solver = 'nystrom', gamma = 0.01)
gl_clf.build_Laplacian()

# %%
v = gl_clf.laplacian_matrix_['V']
e2 = gl_clf.laplacian_matrix_['E']
plt.figure(2)
for i in range(3):
    for j in range(3):
        plt.subplot(3,3,i*3+j+1)
        plt.imshow(v[:,i*3+j+1].reshape(img.shape[0],img.shape[1]))
        plt.axis('off')
plt.rcParams['figure.figsize'] = (10, 10)
plt.tight_layout()  
plt.show()

# %% [markdown]
# Seems to be much richer and uniform in composition. Let's compare their eigencurves:

# %%
plt.figure(3)
a = plt.subplot(1,2,1)
plt.plot(e1)
a.set_ylim([0, 1])
plt.subplot(1,2,2)
plt.plot(e2)
plt.rcParams['figure.figsize'] = (8, 4)
plt.tight_layout()  
plt.show()

# %% [markdown]
# Heuristically, the eigen-curves on the left rise less rapidly to 1 then the right, meaning a less connected graph. Since Nystrom thrives on connectivity, the former is less likely to yield as accurate of an approximation than the latter. However, we see that in order to get the second graph, we had to disable the auto-sigma and manually tune the `rbf` kernel width. Often, the only way to do that is via visual inspection.
